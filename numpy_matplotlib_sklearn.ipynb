# %% [markdown]
# # Numpy, Matplotlib and Sklearn Tutorial

# %% [markdown]
# We often use numpy to handle high dimensional arrays.
#
# Let's try the basic operation of numpy:

# %%
import numpy as np

a = np.array([[1,2,3], [2,3,4]])
print(a.ndim, a.shape, a.size, a.dtype, type(a))

b = np.zeros((3,4))
c = np.ones((3,4))
d = np.random.randn(2,3)
e = np.array([[1,2], [2,3], [3,4]])
f = b*2 - c*3
g = 2*c*f
h = np.dot(a,e)
i = d.mean()
j = d.max(axis=1)
k = a[-1][:2]

#print (a,'\n',b,'\n',c,'\n',d,'\n',e,'\n',f,'\n',g,'\n',h,'\n',i,'\n',j,'\n',k)
# You can print a to k for details
# Out:
# 2 (2, 3) 6 int32 <class 'numpy.ndarray'>

# %% [markdown]
# matplotlib.pyplot provides very useful apis for drawing graphs.
#
# Let's try the basic operation of matplotlib.pyplot:

# %%
import matplotlib.pyplot as plt

x = np.arange(2, 10, 0.2)
print (x)
plt.plot(x, x**1.5*.5, 'r-', x, np.log(x)*5, 'g--', x, x, 'b.')
plt.show()
# Out:
# [2.  2.2 2.4 2.6 2.8 3.  3.2 3.4 3.6 3.8 4.  4.2 4.4 4.6 4.8 5.  5.2 5.4
#  5.6 5.8 6.  6.2 6.4 6.6 6.8 7.  7.2 7.4 7.6 7.8 8.  8.2 8.4 8.6 8.8 9.
#  9.2 9.4 9.6 9.8]

# %% [markdown]
# If you want to print them in different graphs, try this:

# %%
def f(x):
    return np.sin(np.pi*x)

x1 = np.arange(0, 5, 0.1)
x2 = np.arange(0, 5, 0.01)

plt.subplot(211) #两个横轴，一个纵轴，figure 1
plt.plot(x1, f(x1), 'go', x2, f(x2-1))

plt.subplot(212) #两个横轴，一个纵轴，figure 2
plt.plot(x2, f(x2), 'r--')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
def f(t):return np.exp(-t) * np.cos(2*np.pi*t)
t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)
plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')
plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %% [markdown]
# How about printing images?
#
# Let's try to print a image whose pixels gradually change:
#
# Different pixel values represent different gray levels.

# %%
img = np.arange(0, 1, 1/32/32) # define an 1D array with 32x32 elements gradually increasing
img = img.reshape(32, 32) # reshape it into 32x32 array, the array represents a 32x32 image,
                          # each element represents the corresponding pixel of the image
print(img)
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# [[0.00000000e+00 9.76562500e-04 1.95312500e-03 ... 2.83203125e-02
#   2.92968750e-02 3.02734375e-02]
#  [3.12500000e-02 3.22265625e-02 3.32031250e-02 ... 5.95703125e-02
#   6.05468750e-02 6.15234375e-02]
#  [6.25000000e-02 6.34765625e-02 6.44531250e-02 ... 9.08203125e-02
#   9.17968750e-02 9.27734375e-02]
#  ...
#  [9.06250000e-01 9.07226562e-01 9.08203125e-01 ... 9.34570312e-01
#   9.35546875e-01 9.36523438e-01]
#  [9.37500000e-01 9.38476562e-01 9.39453125e-01 ... 9.65820312e-01
#   9.66796875e-01 9.67773438e-01]
#  [9.68750000e-01 9.69726562e-01 9.70703125e-01 ... 9.97070312e-01
#   9.98046875e-01 9.99023438e-01]]

# %% [markdown]
# Based on numpy, Scikit-learn (sklearn) provides a lot of tools for machine learning.It is a very powerful machine learning library.
#
# Then, let's use it for mnist classification:

# %%
from sklearn.datasets import fetch_mldata

# download and read mnist
mnist = fetch_mldata('MNIST original', data_home='./')

# 'mnist.data' is 70k x 784 array, each row represents the pixels from a 28x28=784 image
# 'mnist.target' is 70k x 1 array, each row represents the target class of the corresponding image
images = mnist.data
targets = mnist.target

# make the value of pixels from [0, 255] to [0, 1] for further process
X = mnist.data / 255.
Y = mnist.target

# print the first image of the dataset
img1 = X[0].reshape(28, 28)
plt.imshow(img1, cmap='gray')
plt.show()

# print the images after simple transformation
img2 = 1 - img1
plt.imshow(img2, cmap='gray')
plt.show()

img3 = img1.transpose()
plt.imshow(img3, cmap='gray')
plt.show()
# Out:
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function fetch_mldata is deprecated; fetch_mldata was deprecated in version 0.20 and will be removed in version 0.22
#   warnings.warn(msg, category=DeprecationWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:77: DeprecationWarning: Function mldata_filename is deprecated; mldata_filename was deprecated in version 0.20 and will be removed in version 0.22
#   warnings.warn(msg, category=DeprecationWarning)

# %%
# split data to train and test (for faster calculation, just use 1/10 data)
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X[::10], Y[::10], test_size=1000)

# %% [markdown]
# #### Q1:
# Please use the logistic regression(default parameters) in sklearn to classify the data above, and print the training accuracy and test accuracy.

# %%
# TODO:use logistic regression
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logit = LogisticRegression()
logit.fit(X_train,Y_train)
Y_train_predict_logit = logit.predict(X_train)
Y_test_predict_logit = logit.predict(X_test)


print('Training accuracy: %0.2f%%' % (metrics.accuracy_score(Y_train,Y_train_predict_logit)*100))
print('Testing accuracy: %0.2f%%' % (metrics.accuracy_score(Y_test,Y_test_predict_logit)*100))
# Out:
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:459: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Training accuracy: 95.97%
# Testing accuracy: 87.80%

# %%
#求accuracy的几种方法

##使用内建的score
#print("内建的score,train",logit.score(X_train,Y_train))
#print("内建的score,test",logit.score(X_test,Y_test))

##手动求
#print("手动求",np.mean(Y_train_predict_logit == Y_train))
#print("手动求",np.mean(Y_test_predict_logit == Y_test))

##使用metrics
#print("使用matrix",metrics.accuracy_score(Y_train,Y_train_predict_logit))
#print("使用matrix",metrics.accuracy_score(Y_test,Y_test_predict_logit))

# %% [markdown]
# #### Q2:
# Please use the naive bayes(Bernoulli, default parameters) in sklearn to classify the data above, and print the training accuracy and test accuracy.

# %%
# TODO:use naive bayes
from sklearn.naive_bayes import BernoulliNB
bn = BernoulliNB()
bn.fit(X_train,Y_train)
Y_train_predict_bn = bn.predict(X_train)
Y_test_predict_bn = bn.predict(X_test)

print('Training accuracy: %0.2f%%' % (metrics.accuracy_score(Y_train,Y_train_predict_bn)*100))
print('Testing accuracy: %0.2f%%' % (metrics.accuracy_score(Y_test,Y_test_predict_bn)*100))
# Out:
# Training accuracy: 83.78%
# Testing accuracy: 82.40%

# %% [markdown]
# #### Q3:
# Please use the support vector machine(default parameters) in sklearn to classify the data above, and print the training accuracy and test accuracy.

# %%
# TODO:use support vector machine
from sklearn.svm import LinearSVC
svc = LinearSVC()
svc.fit(X_train,Y_train)
Y_train_predict_svc = svc.predict(X_train)
Y_test_predict_svc = svc.predict(X_test)

print('Training accuracy: %0.2f%%' % (metrics.accuracy_score(Y_train,Y_train_predict_svc)*100))
print('Testing accuracy: %0.2f%%' % (metrics.accuracy_score(Y_test,Y_test_predict_svc)*100))
# Out:
# Training accuracy: 98.30%
# Testing accuracy: 86.10%
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %% [markdown]
# #### Q4:
# Please adjust the parameters of SVM to increase the testing accuracy, and print the training accuracy and test accuracy.

# %%
# TODO:use SVM with another group of parameters
from sklearn.svm import LinearSVC

pa_0 = np.arange(0.01,2.2,0.4)
pa_1 = np.arange(500,2100,500)

a = list()

for i in pa_0:
    for j in pa_1:
        svc = svc = LinearSVC(C=i, max_iter=j)
        svc.fit(X_train,Y_train)
        Y_train_predict_svc = svc.predict(X_train)
        Y_test_predict_svc = svc.predict(X_test)
        a.append([i,j,svc.score(X_train,Y_train),svc.score(X_test,Y_test)])

l = list()
for k in a:
    l.append(k[3])
index = l.index(max(l))
      
print('Training accuracy: %0.2f%%' % (a[index][2]*100))
print('Testing accuracy: %0.2f%%' % (a[index][3]*100))
# Out:
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# Training accuracy: 93.17%
# Testing accuracy: 87.80%
# C:\Users\Jack\Anaconda3\lib\site-packages\sklearn\svm\base.py:922: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
